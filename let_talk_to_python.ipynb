# %% [markdown]
# # LET TALK TO PYTHON

# %% [markdown]
# ## MATH

# %%
6526846*465235756243
# Out:
# 3036522134691599578

# %%
# phep chia
4253265765143/52486355
# Out:
# 81035.64755340698

# %%
676546+6457687325666
# Out:
# 6457688002212

# %%
# phép chia lấy phần nguyên
9 // 2
# Out:
# 4

# %%
# phép cia lấy phân dư
9 % 2
# Out:
# 1

# %%
76 ** 5
# Out:
# 2535525376

# %% [markdown]
# ## STRING

# %%
"HELLO"
# Out:
# 'HELLO'

# %% [markdown]
# ## String operators
#  - concatenation
#  - multiplication

# %%
"HI" * 100000
# Out:
# '...'

# %%
8 + 9
# Out:
# 17

# %% [markdown]
# ## Strings: Indexes
# Rules
#  - ★ Each character’s position is called its index.
#  - ★ Indexes start at 0.
#  - Spaces inside the string are counted.

# %%
"H" + "e" + "l" + "l" + "o"
# Out:
# 'Hello'

# %% [markdown]
# ## String functions

# %%
"lee dưn".upper()
# Out:
# 'LEE DƯN'

# %%
" LEE DƯN".lower()
# Out:
# ' lee dưn'

# %%
len ("This is a string")
# Out:
# 16

# %%
len("   this is a string    ")
# Out:
# 23

# %%
"   this is a string    ".strip()
# Out:
# 'this is a string'

# %%
"#This is a string".startswith("*")
# Out:
# False

# %%
"#This is a string".endswith("g")
# Out:
# True

# %%
# substring
"Hello world"[2]
# Out:
# 'l'

# %%
# substring
"Hello world"[2:]
# Out:
# 'llo world'

# %%
"Hello world"[:5]
# Out:
# 'Hello'

# %%
"Hello world"[-1]
# Out:
# 'd'

# %%
"Hello world"[2:10]
# Out:
# 'llo worl'

# %%
"Hello world"[2:-1]
# Out:
# 'llo worl'

# %%
"Hello world"[1:10:2]
# Out:
# 'el ol'

# %%
"Hello world"[::-1]
# Out:
# 'dlrow olleH'

# %%
a= 14*14

# %%
a
# Out:
# 196

# %%
b= 1576784986437*654356237/76376533

# %%
b
# Out:
# 13509111369103.535

# %%
s=input()

# %%
s

# %%
type(s)

# %%
s+1352

# %%
s=int(input())

# %%
s+725

# %%
len("w3resource.com")

# %%
"w3resource.com"[0:2:-2]

# %%
"w3resource.com"[1:10:2]

# %% [markdown]
# ## Data types

# %%
while True:
    a=int(input("nhập vào một số:"))
    print("giá trị bạn muốn nhập là:",a)
    s=input("bạn có muốn tiếp tục không?(c/k):")
    if s=="c":
        
    break
    print("bye bye")

# %% [markdown]
#    ## FUNCTIONS (HÀM)

# %%
def say_hello():
    print("hello world")

# %%
say_hello()

# %%
# co tham so
def say_hello(myname):
    print("hello", myname)

# %%
say_hello("dwn")

# %% [markdown]
# Bài tập:
# Viết 1 hàm: kiểm tra một số là số lẻ hoặc số chẵn, in ra màn hình "là số lẻ"nếu số đó là só lẻ, "là số chẵn" nếu đó là số chẵn

# %%
def kiem_tra_so(number):
    if number % 2 ==0:
        print("là số chẵn")
    else:
       print("là số lẻ")

# %%
kiem_tra_so(13345)

# %%
def kiem_tra_so(number):
    if number % 2 ==0:
        print("là số chẵn")
    else:
       print("là số lẻ")

# %%
kiem_tra_so(133476347)

# %% [markdown]
# Viết một hàm có tham số là 2 số, in ra kêt quả là tích của 2 số này

# %%
def multiply(so1, so2) :
    print(so1 * so2)

# %%
multiply(524,2549)

# %%
multiply(524,2549)

# %% [markdown]
# ## FUNCTIONS: OUTPUT (GIÁ TRỊ TRẢ VỀ CỦA HÀM)

# %%
def multiply(so1, so2) :
    return so1 * so2

# %%
multiply(644,75476)

# %%
kp = multiply(5434275,8463895)

# %%
kp

# %% [markdown]
# ## input

# %%
def hello_there():
    name = input()
print("Hi", name, "how are you?")

# %%
hello_there()

# %%
65524

# %%
def hello_there():
    print("type your name")
    name = input()
    print("Hi", name , "how are you?")

# %% [markdown]
# ## MODULES

# %% [markdown]
# ## lets't make a game

# %% [markdown]
# Game1:
# Vieets hafm game1 chwas code trong slide 78

# %%
.

# %%
def hello_there():
    print("type your name")
    name = input()
    print("Hi", name , "how are you?")

# %%
from random import randint
def guess2()
    secret_number = randint(1, 10)

    while True:
    guess = input("What number am I thinking of? ")

       if secret_number == guess:
            print("Yay! You got it.")
            break
    else:
            print("No, that's not it.")
# Out:
#   Cell In [4], line 2
#     def guess2()
#                 ^
# SyntaxError: invalid syntax

# %%
def guess1():
    secret_number = 8
    """
    hàm chơi doán số
    """

    guess = input("What number am I thinking of? ")

    if secret_number == guess:
        print("Yay! You got it.")
    else:
        print("No, that's not it.")

# %%
guess1()
# Out:
# What number am I thinking of? 8
# No, that's not it.

# %% [markdown]
# ## Docstring (hướng dẫn sử dụng hàm)

# %%
guess1?

# %%
guess1?

# %%
import mymodules

# %%
mymodules.guess1?
# Out:
# Object `mymodules.guess1` not found.

# %%
mymodules.guess1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 mymodules.guess1
#
# AttributeError: module 'mymodules' has no attribute 'guess1'

# %%
import mymodules

# %%
mymodules.kiem_tra_so
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 mymodules.kiem_tra_so
#
# AttributeError: module 'mymodules' has no attribute 'kiem_tra_so'
